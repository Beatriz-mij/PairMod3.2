# %% [markdown]
# Ejercicios ETL Parte I
# En este caso trabajas en una empresa de venta al por menor de productos italianos y debes realizar la limpieza, transformación e integración de datos de ventas, productos y clientes para su análisis.
#
# Los pasos que deberás seguir en este ejercicio son:
#
# Lectura de la Información:
#
# Leer los archivos CSV (ventas.csv, productos.csv, clientes.csv).
#
# Explorar los conjuntos de datos para comprender su estructura, columnas, tipos de datos, etc.
#
# Transformación de Datos:
#
# Limpiar los datos: manejar valores nulos, eliminar duplicados si los hay, corregir errores tipográficos, etc.
#
# Realizar la integración de datos: unir los conjuntos de datos apropiados para obtener una tabla única que contenga información de ventas junto con detalles de productos y clientes.
#
# Aplicar transformaciones relevantes según sea necesario: por ejemplo, convertir tipos de datos, renombrar columnas, crear nuevas características derivadas, etc.
#
# NOTA Este ejercicio debe realizarse en un archivo .py

# %%
import os
from dotenv import load_dotenv

# %%
import requests
import pandas as pd
import os
from dotenv import load_dotenv

# %%
pd.read_csv("ventas.csv")
# Out:
#     ID_Cliente ID_Producto Fecha_Venta  Cantidad  Total
# 0          723          A1  2023-11-22         2  17.98
# 1          498          C3  2023-11-21         1   5.49
# 2          121          D4  2023-11-20         3  32.97
# 3          885         L12  2023-11-19         1   6.49
# 4          347         Q17  2023-11-18         2   7.98
# ..         ...         ...         ...       ...    ...
# 95         234       AR136  2023-09-04         1   8.45
# 96         987       AS137  2023-09-03         2  12.50
# 97         543       AT138  2023-09-02         1   4.75
# 98         234       AU139  2023-09-01         2   9.98
# 99         987       AV140  2023-08-31         1   5.25
#
# [100 rows x 5 columns]

# %%
df_ventas = pd.read_csv("ventas.csv")
df_ventas.head(5)
# Out:
#    ID_Cliente ID_Producto Fecha_Venta  Cantidad  Total
# 0         723          A1  2023-11-22         2  17.98
# 1         498          C3  2023-11-21         1   5.49
# 2         121          D4  2023-11-20         3  32.97
# 3         885         L12  2023-11-19         1   6.49
# 4         347         Q17  2023-11-18         2   7.98

# %%
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID_Cliente   100 non-null    int64
#  1   ID_Producto  100 non-null    object
#  2   Fecha_Venta  100 non-null    object
#  3   Cantidad     100 non-null    int64
#  4   Total        100 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ KB

# %%
df_ventas.isnull().sum()
# Out:
# ID_Cliente     0
# ID_Producto    0
# Fecha_Venta    0
# Cantidad       0
# Total          0
# dtype: int64

# %%
df_ventas.nunique()
# Out:
# ID_Cliente      30
# ID_Producto    100
# Fecha_Venta     80
# Cantidad         3
# Total           28
# dtype: int64

# %%
df_ventas.drop_duplicates(inplace=True)

# %%
df_ventas.shape
# Out:
# (100, 5)

# %%
df_ventas.sample(10)
# Out:
#     ID_Cliente ID_Producto Fecha_Venta  Cantidad  Total
# 35         987        BH76  2023-11-03         1   4.25
# 10         123        AF32  2023-11-08         2   9.78
# 42         567        BO83  2023-10-27         2  12.50
# 39         876        BL80  2023-10-30         1   6.99
# 36         798        BI77  2023-11-02         2  14.50
# 87         654       AJ128  2023-09-12         1   5.25
# 14         356        AJ36  2023-11-04         2  10.50
# 44         234        BQ85  2023-10-25         2   9.98
# 37         321        BJ78  2023-11-01         1   8.75
# 89         234       AL130  2023-09-10         1   8.45

# %%
pd.read_csv("clientes.csv")
# Out:
#        id  first_name last_name                         email  gender  \
# 0       1       Cheri  Dunsmore      cdunsmore0@instagram.com  Female
# 1       2        Hunt  Bartomeu         hbartomeu1@nsw.gov.au    Male
# 2       3  Michaeline   Paynton            mpaynton2@narod.ru  Female
# 3       4      Filmer    Eirwin            feirwin3@intel.com     NaN
# 4       5      Tanhya   Lubbock  tlubbock4@huffingtonpost.com  Female
# ..    ...         ...       ...                           ...     ...
# 995   996         Ray    Tarpey      rtarpeyrn@bravesites.com  Female
# 996   997        Flem  Roderham       froderhamro@dropbox.com    Male
# 997   998   Winifield    Blakes         wblakesrp@jiathis.com    Male
# 998   999      Lanita  Espinosa        lespinosarq@discuz.net  Female
# 999  1000     Grissel   Siberry     gsiberryrr@wikispaces.com  Female
#
#                             City Country                   Address
# 0              Palma De Mallorca   Spain  076 Rockefeller Crossing
# 1                           Lugo   Spain        0046 Utah Junction
# 2                            NaN   Spain          0 Corry Crossing
# 3                           Leon   Spain       5 American Ash Road
# 4    Hospitalet De Llobregat, L'   Spain         9289 Merry Circle
# ..                           ...     ...                       ...
# 995                       Zamora   Spain     36384 Sommers Terrace
# 996                   Pontevedra   Spain    93177 Eastwood Parkway
# 997                         Vigo   Spain       03044 Grayhawk Road
# 998                 Dos Hermanas   Spain        2 Schmedeman Drive
# 999                         Leon   Spain     42274 Waywood Terrace
#
# [1000 rows x 8 columns]

# %%
df_clientes = pd.read_csv("clientes.csv")
df_clientes.head(10)
# Out:
#    id  first_name   last_name                         email  gender  \
# 0   1       Cheri    Dunsmore      cdunsmore0@instagram.com  Female
# 1   2        Hunt    Bartomeu         hbartomeu1@nsw.gov.au    Male
# 2   3  Michaeline     Paynton            mpaynton2@narod.ru  Female
# 3   4      Filmer      Eirwin            feirwin3@intel.com     NaN
# 4   5      Tanhya     Lubbock  tlubbock4@huffingtonpost.com  Female
# 5   6       Stacy  Minchinton        sminchinton5@ameblo.jp    Male
# 6   7        Harv      Sandes              hsandes6@who.int    Male
# 7   8      Aubree       Jirsa                           NaN  Female
# 8   9       Tymon     Darragh             tdarragh8@free.fr    Male
# 9  10        Igor     Dwelley          idwelley9@flickr.com    Male
#
#                           City Country                   Address
# 0            Palma De Mallorca   Spain  076 Rockefeller Crossing
# 1                         Lugo   Spain        0046 Utah Junction
# 2                          NaN   Spain          0 Corry Crossing
# 3                         Leon   Spain       5 American Ash Road
# 4  Hospitalet De Llobregat, L'   Spain         9289 Merry Circle
# 5            Palma De Mallorca   Spain         4 Meadow Vale Way
# 6                       Lleida   Spain       20 Menomonie Circle
# 7                    Santander     NaN         8294 Schurz Court
# 8                          NaN   Spain          41 Trailsway Way
# 9                         Lugo   Spain                       NaN

# %%
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       973 non-null    object
#  4   gender      923 non-null    object
#  5   City        876 non-null    object
#  6   Country     846 non-null    object
#  7   Address     959 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 62.6+ KB

# %%
df_clientes.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'City', 'Country',
#        'Address'],
#       dtype='object')

# %%
df_clientes.isnull().sum()
# Out:
# id              0
# first_name      0
# last_name       0
# email          27
# gender         77
# City          124
# Country       154
# Address        41
# dtype: int64

# %%
df_clientes.nunique()
# Out:
# id            1000
# first_name     940
# last_name      986
# email          973
# gender           8
# City            55
# Country          1
# Address        958
# dtype: int64

# %%
df_clientes.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df_clientes.drop_duplicates(inplace=True)

# %%
df_clientes.shape
# Out:
# (1000, 8)

# %%
df_clientes.sample(10)
# Out:
#       id  first_name  last_name                       email       gender  \
# 628  629     Opaline       Alti           oaltihg@ifeng.com          NaN
# 58    59        Marj     Fetter            mfetter1m@go.com       Female
# 73    74        Tate   Capehorn     tcapehorn21@comsenz.com         Male
# 873  874        Roch    Twamley   rtwamleyo9@yellowbook.com     Bigender
# 610  611     Jacinda      Kenna         jkennagy@sbwire.com       Female
# 482  483    Clemente     Ruthen  cruthende@seattletimes.com         Male
# 642  643        Matt     Bishop        mbishophu@discuz.net   Non-binary
# 992  993  Evangelina     Dutton    eduttonrk@altervista.org  Genderqueer
# 649  650        Anna  Edinburgh      aedinburghi1@salon.com       Female
# 439  440      Kalila  Goldspink                         NaN       Female
#
#                        City Country                Address
# 628                     NaN   Spain    4934 Heath Junction
# 58                 Valencia     NaN        964 Veith Drive
# 73                Barcelona   Spain                    NaN
# 873                  Getafe     NaN  1019 Maywood Junction
# 610                     NaN   Spain        48639 Erie Park
# 482                 Granada     NaN  9 Crescent Oaks Point
# 642  Donostia-San Sebastian   Spain    414 Forster Terrace
# 992                  Girona   Spain        60 Redwing Road
# 649               Coruña, A   Spain         6603 Ryan Hill
# 439                 Sevilla     NaN      973 Loomis Avenue

# %%
df_clientes.fillna("Desconocido",inplace=True)

# %%
df_clientes.head(10)
# Out:
#    id  first_name   last_name                         email       gender  \
# 0   1       Cheri    Dunsmore      cdunsmore0@instagram.com       Female
# 1   2        Hunt    Bartomeu         hbartomeu1@nsw.gov.au         Male
# 2   3  Michaeline     Paynton            mpaynton2@narod.ru       Female
# 3   4      Filmer      Eirwin            feirwin3@intel.com  Desconocido
# 4   5      Tanhya     Lubbock  tlubbock4@huffingtonpost.com       Female
# 5   6       Stacy  Minchinton        sminchinton5@ameblo.jp         Male
# 6   7        Harv      Sandes              hsandes6@who.int         Male
# 7   8      Aubree       Jirsa                   Desconocido       Female
# 8   9       Tymon     Darragh             tdarragh8@free.fr         Male
# 9  10        Igor     Dwelley          idwelley9@flickr.com         Male
#
#                           City      Country                   Address
# 0            Palma De Mallorca        Spain  076 Rockefeller Crossing
# 1                         Lugo        Spain        0046 Utah Junction
# 2                  Desconocido        Spain          0 Corry Crossing
# 3                         Leon        Spain       5 American Ash Road
# 4  Hospitalet De Llobregat, L'        Spain         9289 Merry Circle
# 5            Palma De Mallorca        Spain         4 Meadow Vale Way
# 6                       Lleida        Spain       20 Menomonie Circle
# 7                    Santander  Desconocido         8294 Schurz Court
# 8                  Desconocido        Spain          41 Trailsway Way
# 9                         Lugo        Spain               Desconocido

# %%
df_clientes.isnull().sum()
# Out:
# id            0
# first_name    0
# last_name     0
# email         0
# gender        0
# City          0
# Country       0
# Address       0
# dtype: int64

# %%
pd.read_csv("productos_1.csv",sep=";")
# Out:
#       ID                 Nombre_Producto             Categoría  Precio  \
# 0     A1                Pizza Margherita     Platos Preparados    8.99
# 1     B2          Risotto de Champiñones     Platos Preparados    6.75
# 2     C3                        Tiramisú               Postres    5.49
# 3     D4                       Panettone            Repostería   10.99
# 4     E5                     Orecchiette       Productos Secos    4.29
# 5     F6             Polenta Tradicional               Harinas    3.75
# 6     G7            Mozzarella di Bufala     Productos Lácteos    9.25
# 7     H8                  Pesto Genovese                Salsas    5.99
# 8     I9               Lasagna Bolognesa     Platos Preparados    7.49
# 9    J10                   Arroz Arborio       Productos Secos    4.89
# 10   K11                   Café Espresso                  Café    6.49
# 11   L12     Sardinas en Aceite de Oliva  Pescados en Conserva    3.99
# 12   M13                     Pesto Rosso                Salsas    4.75
# 13   N14               Gnocchi de Patata  Productos Congelados    5.25
# 14   O15  Ravioli de Ricotta y Espinacas  Productos Congelados    6.75
# 15   P16                        Caponata                Salsas    4.25
# 16   Q17                  Pasta de Trigo       Productos Secos    3.99
# 17   R18          Salsa de Tomate Casera                Salsas    2.49
# 18   S19    Aceite de Oliva Virgen Extra               Aceites    9.99
# 19   T20                 Queso Parmesano     Productos Lácteos    7.89
# 20   U21                  Salami Toscano             Embutidos    5.75
# 21   V22             Prosciutto di Parma             Embutidos   12.45
# 22   W23                 Gelato de Limón               Helados    4.25
# 23   X24                         Cannoli                Dulces    3.99
# 24   Y25                      Cacciatore             Embutidos    6.75
# 25   Z26                         Calzone                Pizzas    7.49
# 26  AA27           Caponata di Melanzane             Entrantes    4.89
# 27  BB28                     Cappelletti       Productos Secos    5.25
# 28  CC29                       Carbonara     Platos Preparados    8.75
# 29  DD30                Carciofi Ripieni              Verduras    6.99
# 30  EE31                      Casatiello            Repostería    9.45
# 31  FF32               Cassata Siciliana               Postres   10.99
# 32  GG33                   Ciceri e Tria     Platos Preparados    5.89
#
#     Origen                                        Descripción
# 0   Italia  Clásica pizza italiana con tomate, mozzarella ...
# 1   Italia  Risotto cremoso con champiñones frescos, una d...
# 2   Italia  Postre clásico italiano con capas de bizcocho ...
# 3   Italia  Pan dulce navideño italiano con frutas confita...
# 4   Italia  Pequeñas pastas con forma de orecchiette ideal...
# 5   Italia  Harina de maíz italiana para preparar la tradi...
# 6   Italia  Mozzarella fresca elaborada con leche de búfal...
# 7   Italia  Una salsa italiana de albahaca, piñones, queso...
# 8   Italia  Clásica lasaña con salsa boloñesa, bechamel y ...
# 9   Italia  Arroz de grano corto perfecto para risottos it...
# 10  Italia  Café espresso italiano con un aroma y sabor in...
# 11  Italia  Sardinas frescas en aceite de oliva, un bocado...
# 12  Italia  Una variante italiana del pesto con tomates se...
# 13  Italia  Gnocchi de patata italiana, ideales con salsa ...
# 14  Italia  Raviolis rellenos de ricotta y espinacas fresc...
# 15  Italia  Una clásica caponata siciliana con berenjenas,...
# 16  Italia  Deliciosa pasta de trigo durum italiana, ideal...
# 17  Italia  Elaborada con tomates italianos maduros, una r...
# 18  Italia  Aceite de oliva prensado en frío de las mejore...
# 19  Italia  El famoso queso italiano, madurado durante mes...
# 20  Italia  Salami de cerdo italiano curado con hierbas y ...
# 21  Italia  Delicioso jamón curado, famoso por su sabor y ...
# 22  Italia  Gelato italiano cremoso con sabor a limón fres...
# 23  Italia  Postre siciliano con masa crujiente rellena de...
# 24  Italia  Salchichas de cerdo condimentadas con hierbas ...
# 25  Italia  Pizza cerrada y horneada, rellena de queso, sa...
# 26  Italia  Entrante italiano con berenjenas, tomate, apio...
# 27  Italia  Pasta rellena parecida al ravioli, típica de l...
# 28  Italia  Pasta con salsa de huevo, queso, panceta y pim...
# 29  Italia  Alcachofas rellenas con pan rallado, ajo, pere...
# 30  Italia  Pan salado italiano con huevos, salami, queso ...
# 31  Italia  Tarta siciliana con capas de bizcocho, ricotta...
# 32  Italia  Plato de pasta tradicional de Apulia con garba...
